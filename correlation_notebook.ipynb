# %%
#libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data
my_df = pd.read_csv("wine.csv")

# %%
# run correlation matrix and plot
f, ax = plt.subplots(figsize=(18, 14))
corr = my_df.corr()
sns_plot = sns.heatmap(corr, mask=np.zeros_like(corr,dtype=bool),
                       cmap=sns.diverging_palette(220, 10, as_cmap=True),
                       square=True, ax=ax,vmin=-1,vmax=1)
plt.title("Pearson's Correlation")
# Out:
# Text(0.5, 1.0, "Pearson's Correlation")

# %%
#save figure
fig = sns_plot.get_figure()
fig.savefig("output_corr.png")

# %%
#no class data

# %%
# import data
my_df2 = my_df.drop('class', axis=1)
my_df2
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
# run correlation matrix and plot
f2, ax2 = plt.subplots(figsize=(18, 14))
corr2 = my_df2.corr()
sns_plot2 = sns.heatmap(corr2, mask=np.zeros_like(corr2, dtype=bool),
	cmap=sns.diverging_palette(220, 10, as_cmap=True),
	square=True, ax=ax2,vmin=-1,vmax=1)
plt.title("Pearson's Correlation")
# Out:
# Text(0.5, 1.0, "Pearson's Correlation")

# %%
#save figure
fig2 = sns_plot2.get_figure()
fig2.savefig("output_corr2.png")

# %%
#spearman's

# %%
# run correlation matrix and plot
f3, ax3 = plt.subplots(figsize=(18, 14))
corr3 = my_df2.corr(method="spearman")
sns_plot3 = sns.heatmap(corr3, mask=np.zeros_like(corr3, dtype=bool),
	cmap=sns.diverging_palette(220, 10, as_cmap=True),
	square=True, ax=ax3,vmin=-1,vmax=1)
plt.title("Spearman's Correlation")
# Out:
# Text(0.5, 1.0, "Spearman's Correlation")

# %%
#save figure
fig3 = sns_plot3.get_figure()
fig3.savefig("output_corr3.png")

# %%
#kendall's

# %%
# run correlation matrix and plot
f4, ax4 = plt.subplots(figsize=(18, 14))
corr4 = my_df2.corr(method="kendall")
#~ print(corr4)
sns_plot4 = sns.heatmap(corr4, mask=np.zeros_like(corr4, dtype=bool),
	cmap=sns.diverging_palette(220, 10, as_cmap=True),
	square=True, ax=ax4,vmin=-1,vmax=1)
plt.title("Kendall's Correlation")
# Out:
# Text(0.5, 1.0, "Kendall's Correlation")

# %%
#save figure
fig4 = sns_plot4.get_figure()
fig4.savefig("output_corr4.png")

# %%
# checking relationships between examples

# %%
# import data
my_df3 = my_df2.T
# run correlation matrix and plot
f5, ax5 = plt.subplots(figsize=(18, 14))
corr5 = my_df3.corr(method="pearson")
#~ print(corr4)
sns_plot5 = sns.heatmap(corr5, mask=np.zeros_like(corr5, dtype=bool),
	cmap=sns.diverging_palette(220, 10, as_cmap=True),
	square=True, ax=ax5)
plt.title("Pearson's Correlation")
# Out:
# Text(0.5, 1.0, "Pearson's Correlation")

# %%
#save figure
fig5 = sns_plot5.get_figure()
fig5.savefig("output_corr5.png")
